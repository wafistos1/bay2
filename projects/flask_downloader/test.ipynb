# %%
def first_non_repeating_letter(string):
    #your code here
    for t in string.lower():
        print('T', t)
        toto1 = [*string.lower()]
        try:
            toto1.remove(t)
            toto1.remove(t)
        except ValueError:
            print('tt', t)
            return t
    return ''

# %%
toto1 = [*toto.lower()]
toto1.remove(',')
toto1.remove(',')
toto1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [73], line 3
#       1 toto1 = [*toto.lower()]
#       2 toto1.remove(',')
# ----> 3 toto1.remove(',')
#       4 toto1
#
# ValueError: list.remove(x): x not in list

# %%
toto = 'sT,rtzbeSS'
# toto1 = [*toto.lower()]
# type(toto1)

# %%
toto.count('S')
# Out:
# 2

# %%
wafi = first_non_repeating_letter(toto)

print(wafi)
# Out:
# T s
# T t
# T ,
# tt ,
# ,

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 string.lower()
#
# NameError: name 'string' is not defined
